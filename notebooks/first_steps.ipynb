# %% [markdown]
# # Installing and Running Voila

# %% [markdown]
# To install Voila for dashboarding with Jupyter notebooks and set up an example notebook, follow these instructions:
#
# 1. Install Voila:
#
#     - Open a terminal or command prompt.
#     - Ensure you have an active Python environment (e.g., virtual environment).
#     - Run the following command to install Voila using pip:
#     - `pip install voila pandas jupyter` etc

# %% [markdown]
# 2. Launch Voila:
#
#     - Open a terminal or command prompt.
#     - Navigate to the directory containing your Jupyter notebook.
#     - Run the following command to launch Voila and serve your notebook as a dashboard:
#     ` voila <notebook_name>.ipynb`
#     -  Replace <notebook_name>.ipynb with the actual name of your Jupyter notebook file.

# %% [markdown]
# 3. Access the dashboard:
#
#     - Once Voila is running, it will display a local web server address (e.g., http://localhost:8866/).
#     - Open a web browser and enter the provided address to access your Voila dashboard.
#     - You can share this URL with others to allow them to view the dashboard.

# %% [markdown]
# # Getting Started

# %%
# Import libraries
from dotenv import load_dotenv
import os
import psycopg
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

# %%
from os import environ as env

if 'readonly_user' in env:
    print(env['readonly_user'])

# Should return your username you were given earlier
# >>> analyst
# Out:
# analyst

# %%
# Load environment variables
load_dotenv()
db_user = os.getenv('readonly_user')
db_password = os.getenv('readonly_user_password')
db_host = os.getenv('database_endpoint')
db_name = os.getenv('db_name')

# %%
# Connect to the Stack Overflow database
conn = psycopg.connect(
    host=db_host,
    dbname=db_name,
    user=db_user,
    password=db_password
)

# %%
# Define HEART metrics for Stack Overflow
heart_metrics = {
    'Happiness': 'Measure of user satisfaction and happiness with the Questions & Answers product.',
    'Engagement': 'Measure of user interaction and activity on the platform.',
    'Adoption': 'Measure of user acquisition and growth of Stack Overflow user base.',
    'Retention': 'Measure of user retention and continued usage of the platform over time.',
    'Task Success': 'Measure of user ability to accomplish their goals and tasks effectively on Stack Overflow.'
}

# %% [markdown]
# ### Create a SQLalchemy Engine
#
# Use the following code to connect to the DB and transfer the results to `pandas` more easily for exploration.

# %%
from sqlalchemy import create_engine


# With the env variables loaded we can insert them into the engine connection string.
engine = create_engine(f"postgresql+psycopg://{env['readonly_user']}:{env['readonly_user_password']}@{env['database_endpoint']}/{env['db_name']}")
connection = engine.connect()

# %% [markdown]
# Test the connection engine

# %%
query = "SELECT * FROM users LIMIT 5"
df = pd.read_sql(query, connection)
df
# Out:
#          id  account_id  reputation  views  down_votes  up_votes  \
# 0  18151768    24192764           1      0           0         0
# 1  18151769    24192766           1      0           0         0
# 2  18151770    24192767           1      0           0         0
# 3  18151771    24192768           1      1           0         0
# 4  18151772    24192769           1      0           0         0
#
#         display_name location profile_image_url  \
# 0   Flores Macdonald     None              None
# 1       user18151769     None              None
# 2              rsonx     None              None
# 3            Akabane     None              None
# 4  Markus Schlotbohm     None              None
#
#                                          website_url  \
# 0  https://vidhyamitra.com/what-is-raj-yoga-in-as...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                             about_me           creation_date  \
# 0  <p>Through Raja Yoga, the person gains power, ... 2022-02-08 12:55:57.117
# 1                                               None 2022-02-08 12:56:11.793
# 2                                               None 2022-02-08 12:56:17.653
# 3                                               None 2022-02-08 12:56:49.530
# 4                                               None 2022-02-08 12:56:50.073
#
#          last_access_date
# 0 2022-02-08 13:26:31.297
# 1 2022-12-15 10:43:59.007
# 2 2022-02-08 14:57:14.440
# 3 2022-05-05 21:17:57.123
# 4 2022-09-30 08:20:38.757

# %% [markdown]
# # Example Metric Analysis
#
# Let's take a look at one of the HEART metrics, Adoption.
#
# First of all, as an example, we are going to load in the data from the Users table and identify how many unique users signed up per month. I will give the following code using Pandas, we will then go onto using SQL equivalents that you may find more helpful, and indeed faster, in order to complete your project.

# %% [markdown]
# SQL query to select all users and order by creation_date

# %%
query = "SELECT * FROM users ORDER BY creation_date LIMIT 50000"
df = pd.read_sql(query, connection)

# %% [markdown]
# 1. Set the creation_date column to datetime format
# 2. create a new column c_date which is equal to the creation_date column but formatted into date format instead of datetime
# 3. display the c_date column

# %%
df['creation_date'] = pd.to_datetime(df['creation_date'])

df['c_date'] = df['creation_date'].dt.date

df['c_date']
# Out:
# 0        2008-07-31
# 1        2008-07-31
# 2        2008-07-31
# 3        2008-07-31
# 4        2008-07-31
#             ...
# 49995    2009-07-15
# 49996    2009-07-15
# 49997    2009-07-15
# 49998    2009-07-15
# 49999    2009-07-15
# Name: c_date, Length: 50000, dtype: object

# %%
pd.DatetimeIndex(df['c_date']).to_period("M")

df.head()
# Out:
#    id  account_id  reputation   views  down_votes  up_votes  display_name  \
# 0  -1          -1           1  127553     1486341    591286     Community
# 1   1           1       63031  592599        1312      3407   Jeff Atwood
# 2   2           2        6076   31851          88       671  Geoff Dalgas
# 3   3           3       15657   29678         100      7932  Jarrod Dixon
# 4   4           4       33192   83720         100       855  Joel Spolsky
#
#                 location profile_image_url                     website_url  \
# 0     on the server farm              None  https://meta.stackexchange.com
# 1         El Cerrito, CA              None  https://blog.codinghorror.com/
# 2          Corvallis, OR              None        http://stackoverflow.com
# 3  Johnson City, TN, USA              None          http://jarroddixon.com
# 4           New York, NY              None     https://joelonsoftware.com/
#
#                                             about_me           creation_date  \
# 0  <p>Hi, I'm not really a person.</p>\n<p>I'm a ... 2008-07-31 00:00:00.000
# 1  <p><a href="https://blog.codinghorror.com/stac... 2008-07-31 14:22:31.287
# 2  <p>Dev #2 who helped create Stack Overflow cur... 2008-07-31 14:22:31.287
# 3  <p>Former <a href="http://blog.stackoverflow.c... 2008-07-31 14:22:31.287
# 4  <p>In 2000 I co-founded Fog Creek Software, wh... 2008-07-31 14:22:31.317
#
#          last_access_date      c_date
# 0 2008-08-26 00:16:53.810  2008-07-31
# 1 2023-01-27 20:51:56.877  2008-07-31
# 2 2023-03-03 16:55:29.527  2008-07-31
# 3 2022-12-14 04:49:01.427  2008-07-31
# 4 2023-02-02 15:58:51.410  2008-07-31

# %% [markdown]
# We will plot the months of the year along the x axis and the number of new users per month on the y axis
#
# - set the period variable to monthly, using the to_period method
# - y is equal to the number of new users per month
# - x is equal to the months
# - convert x from date to string for plotting on axis

# %%
period = df['creation_date'].dt.to_period("M")

y = period.value_counts()

x = period.unique()

x = x.astype(str)

# %%
fig = plt.figure(figsize = (12, 5))
 
# creating the bar plot
plt.bar(x, y, color ='maroon',
        width = 0.5)

plt.ylabel("Signups per Month")
plt.xlabel("Date")
plt.title("Stack Overflow Signups per Month (first 50k Users)")
plt.show()

# %% [markdown]
# ## Example Metric SQL
#
# Let's look at the same metric again, but this time across the entire table, and with more SQL queries.
#
# We'll start off with grouping together Months, Years, and counting the entries for them so that we might see how Users have Adopted the service. We can begin by running SQL directly in our notebooks, then move onto loading that information into something more manageable.

# %%
# %load_ext sql

# %%
# %sql postgresql+psycopg://{env['readonly_user']}:{env['readonly_user_password']}@{env['database_endpoint']}/{env['db_name']}

# %%
# %%sql
#
# SELECT
#        EXTRACT(YEAR FROM creation_date) AS Year,
#        EXTRACT(MONTH FROM creation_date) AS Month,
#        COUNT(*) AS Count
# FROM users
# GROUP BY Year, Month
# ORDER BY Year, Month
# Out:
#  * postgresql+psycopg://analyst:***@terraform-20231114113407120500000001.cfmnnswnfhpn.eu-west-2.rds.amazonaws.com/stackoverflow
# 177 rows affected.
# [(Decimal('2008'), Decimal('7'), 9),
#  (Decimal('2008'), Decimal('8'), 2806),
#  (Decimal('2008'), Decimal('9'), 9643),
#  (Decimal('2008'), Decimal('10'), 3544),
#  (Decimal('2008'), Decimal('11'), 2857),
#  (Decimal('2008'), Decimal('12'), 2776),
#  (Decimal('2009'), Decimal('1'), 3294),
#  (Decimal('2009'), Decimal('2'), 3557),
#  (Decimal('2009'), Decimal('3'), 4114),
#  (Decimal('2009'), Decimal('4'), 4203),
#  (Decimal('2009'), Decimal('5'), 5321),
#  (Decimal('2009'), Decimal('6'), 5379),
#  (Decimal('2009'), Decimal('7'), 5668),
#  (Decimal('2009'), Decimal('8'), 5724),
#  (Decimal('2009'), Decimal('9'), 5698),
#  (Decimal('2009'), Decimal('10'), 10063),
#  (Decimal('2009'), Decimal('11'), 12890),
#  (Decimal('2009'), Decimal('12'), 12039),
#  (Decimal('2010'), Decimal('1'), 13064),
#  (Decimal('2010'), Decimal('2'), 12307),
#  (Decimal('2010'), Decimal('3'), 14149),
#  (Decimal('2010'), Decimal('4'), 15019),
#  (Decimal('2010'), Decimal('5'), 15757),
#  (Decimal('2010'), Decimal('6'), 16414),
#  (Decimal('2010'), Decimal('7'), 17442),
#  (Decimal('2010'), Decimal('8'), 18251),
#  (Decimal('2010'), Decimal('9'), 17011),
#  (Decimal('2010'), Decimal('10'), 18444),
#  (Decimal('2010'), Decimal('11'), 20307),
#  (Decimal('2010'), Decimal('12'), 20933),
#  (Decimal('2011'), Decimal('1'), 24470),
#  (Decimal('2011'), Decimal('2'), 26226),
#  (Decimal('2011'), Decimal('3'), 30745),
#  (Decimal('2011'), Decimal('4'), 29442),
#  (Decimal('2011'), Decimal('5'), 29276),
#  (Decimal('2011'), Decimal('6'), 29588),
#  (Decimal('2011'), Decimal('7'), 31593),
#  (Decimal('2011'), Decimal('8'), 32445),
#  (Decimal('2011'), Decimal('9'), 31815),
#  (Decimal('2011'), Decimal('10'), 30241),
#  (Decimal('2011'), Decimal('11'), 31922),
#  (Decimal('2011'), Decimal('12'), 30730),
#  (Decimal('2012'), Decimal('1'), 35031),
#  (Decimal('2012'), Decimal('2'), 37639),
#  (Decimal('2012'), Decimal('3'), 40345),
#  (Decimal('2012'), Decimal('4'), 39075),
#  (Decimal('2012'), Decimal('5'), 57086),
#  (Decimal('2012'), Decimal('6'), 58499),
#  (Decimal('2012'), Decimal('7'), 67798),
#  (Decimal('2012'), Decimal('8'), 66114),
#  (Decimal('2012'), Decimal('9'), 64136),
#  (Decimal('2012'), Decimal('10'), 73445),
#  (Decimal('2012'), Decimal('11'), 72027),
#  (Decimal('2012'), Decimal('12'), 67133),
#  (Decimal('2013'), Decimal('1'), 81363),
#  (Decimal('2013'), Decimal('2'), 84364),
#  (Decimal('2013'), Decimal('3'), 100335),
#  (Decimal('2013'), Decimal('4'), 100342),
#  (Decimal('2013'), Decimal('5'), 97784),
#  (Decimal('2013'), Decimal('6'), 89197),
#  (Decimal('2013'), Decimal('7'), 96135),
#  (Decimal('2013'), Decimal('8'), 89703),
#  (Decimal('2013'), Decimal('9'), 90340),
#  (Decimal('2013'), Decimal('10'), 102475),
#  (Decimal('2013'), Decimal('11'), 98409),
#  (Decimal('2013'), Decimal('12'), 91047),
#  (Decimal('2014'), Decimal('1'), 102136),
#  (Decimal('2014'), Decimal('2'), 100504),
#  (Decimal('2014'), Decimal('3'), 108247),
#  (Decimal('2014'), Decimal('4'), 100401),
#  (Decimal('2014'), Decimal('5'), 96322),
#  (Decimal('2014'), Decimal('6'), 89740),
#  (Decimal('2014'), Decimal('7'), 97628),
#  (Decimal('2014'), Decimal('8'), 90529),
#  (Decimal('2014'), Decimal('9'), 94772),
#  (Decimal('2014'), Decimal('10'), 100877),
#  (Decimal('2014'), Decimal('11'), 99046),
#  (Decimal('2014'), Decimal('12'), 93333),
#  (Decimal('2015'), Decimal('1'), 98917),
#  (Decimal('2015'), Decimal('2'), 96782),
#  (Decimal('2015'), Decimal('3'), 110007),
#  (Decimal('2015'), Decimal('4'), 110231),
#  (Decimal('2015'), Decimal('5'), 101194),
#  (Decimal('2015'), Decimal('6'), 101972),
#  (Decimal('2015'), Decimal('7'), 106333),
#  (Decimal('2015'), Decimal('8'), 100618),
#  (Decimal('2015'), Decimal('9'), 103378),
#  (Decimal('2015'), Decimal('10'), 109937),
#  (Decimal('2015'), Decimal('11'), 106353),
#  (Decimal('2015'), Decimal('12'), 105237),
#  (Decimal('2016'), Decimal('1'), 124519),
#  (Decimal('2016'), Decimal('2'), 123702),
#  (Decimal('2016'), Decimal('3'), 136304),
#  (Decimal('2016'), Decimal('4'), 128220),
#  (Decimal('2016'), Decimal('5'), 124911),
#  (Decimal('2016'), Decimal('6'), 122238),
#  (Decimal('2016'), Decimal('7'), 120248),
#  (Decimal('2016'), Decimal('8'), 113436),
#  (Decimal('2016'), Decimal('9'), 120645),
#  (Decimal('2016'), Decimal('10'), 146399),
#  (Decimal('2016'), Decimal('11'), 131392),
#  (Decimal('2016'), Decimal('12'), 121617),
#  (Decimal('2017'), Decimal('1'), 130376),
#  (Decimal('2017'), Decimal('2'), 135952),
#  (Decimal('2017'), Decimal('3'), 156489),
#  (Decimal('2017'), Decimal('4'), 140899),
#  (Decimal('2017'), Decimal('5'), 144975),
#  (Decimal('2017'), Decimal('6'), 140246),
#  (Decimal('2017'), Decimal('7'), 150230),
#  (Decimal('2017'), Decimal('8'), 144394),
#  (Decimal('2017'), Decimal('9'), 151634),
#  (Decimal('2017'), Decimal('10'), 158170),
#  (Decimal('2017'), Decimal('11'), 151971),
#  (Decimal('2017'), Decimal('12'), 118892),
#  (Decimal('2018'), Decimal('1'), 133380),
#  (Decimal('2018'), Decimal('2'), 124938),
#  (Decimal('2018'), Decimal('3'), 148180),
#  (Decimal('2018'), Decimal('4'), 137344),
#  (Decimal('2018'), Decimal('5'), 150185),
#  (Decimal('2018'), Decimal('6'), 133727),
#  (Decimal('2018'), Decimal('7'), 142112),
#  (Decimal('2018'), Decimal('8'), 135407),
#  (Decimal('2018'), Decimal('9'), 132979),
#  (Decimal('2018'), Decimal('10'), 145822),
#  (Decimal('2018'), Decimal('11'), 137744),
#  (Decimal('2018'), Decimal('12'), 119740),
#  (Decimal('2019'), Decimal('1'), 141626),
#  (Decimal('2019'), Decimal('2'), 131530),
#  (Decimal('2019'), Decimal('3'), 147458),
#  (Decimal('2019'), Decimal('4'), 143667),
#  (Decimal('2019'), Decimal('5'), 146629),
#  (Decimal('2019'), Decimal('6'), 132793),
#  (Decimal('2019'), Decimal('7'), 140594),
#  (Decimal('2019'), Decimal('8'), 134702),
#  (Decimal('2019'), Decimal('9'), 136850),
#  (Decimal('2019'), Decimal('10'), 154679),
#  (Decimal('2019'), Decimal('11'), 146629),
#  (Decimal('2019'), Decimal('12'), 157815),
#  (Decimal('2020'), Decimal('1'), 170505),
#  (Decimal('2020'), Decimal('2'), 156743),
#  (Decimal('2020'), Decimal('3'), 182691),
#  (Decimal('2020'), Decimal('4'), 260011),
#  (Decimal('2020'), Decimal('5'), 198459),
#  (Decimal('2020'), Decimal('6'), 184896),
#  (Decimal('2020'), Decimal('7'), 172378),
#  (Decimal('2020'), Decimal('8'), 164703),
#  (Decimal('2020'), Decimal('9'), 167666),
#  (Decimal('2020'), Decimal('10'), 181812),
#  (Decimal('2020'), Decimal('11'), 178651),
#  (Decimal('2020'), Decimal('12'), 178598),
#  (Decimal('2021'), Decimal('1'), 194773),
#  (Decimal('2021'), Decimal('2'), 180806),
#  (Decimal('2021'), Decimal('3'), 217425),
#  (Decimal('2021'), Decimal('4'), 230487),
#  (Decimal('2021'), Decimal('5'), 281437),
#  (Decimal('2021'), Decimal('6'), 260539),
#  (Decimal('2021'), Decimal('7'), 212139),
#  (Decimal('2021'), Decimal('8'), 227715),
#  (Decimal('2021'), Decimal('9'), 242918),
#  (Decimal('2021'), Decimal('10'), 244758),
#  (Decimal('2021'), Decimal('11'), 254055),
#  (Decimal('2021'), Decimal('12'), 238634),
#  (Decimal('2022'), Decimal('1'), 275281),
#  (Decimal('2022'), Decimal('2'), 249595),
#  (Decimal('2022'), Decimal('3'), 306966),
#  (Decimal('2022'), Decimal('4'), 350610),
#  (Decimal('2022'), Decimal('5'), 235591),
#  (Decimal('2022'), Decimal('6'), 209204),
#  (Decimal('2022'), Decimal('7'), 203003),
#  (Decimal('2022'), Decimal('8'), 226219),
#  (Decimal('2022'), Decimal('9'), 239261),
#  (Decimal('2022'), Decimal('10'), 246316),
#  (Decimal('2022'), Decimal('11'), 264690),
#  (Decimal('2022'), Decimal('12'), 249281),
#  (Decimal('2023'), Decimal('1'), 217014),
#  (Decimal('2023'), Decimal('2'), 184360),
#  (Decimal('2023'), Decimal('3'), 26716)]

# %% [markdown]
# This query takes a long time and spits out a long list, so lets perform the query once and store the information in a DataFrame.
#
# We may also want to combine the Year and Month columns in order to better plot our findings later. Instead of doing that in Pandas, lets do it directly in the SQL query.

# %%
# Load environment variables
load_dotenv()
db_user = os.getenv('readonly_user')
db_password = os.getenv('readonly_user_password')
db_host = os.getenv('database_endpoint')
db_name = os.getenv('db_name')

db_params = {
    'dbname': db_name,
    'user': db_user,
    'password': db_password,
    'host': db_host,
    'port': 5432
}

# Create a database connection
conn = psycopg.connect(**db_params)

# Your SQL query
sql_query = """
SELECT TO_CHAR(creation_date, 'YYYY-MM') AS YearMonth,
       COUNT(*) AS Count 
FROM users 
GROUP BY YearMonth
ORDER BY YearMonth;
"""

# Load the query result into a DataFrame
df = pd.read_sql(sql_query, conn)

# Close the database connection
conn.close()

# Now you have your query results in the 'df' DataFrame
print(df)
# Out:
# /var/folders/60/1x07n04s69n5zj91gyj5fyrh0000gn/T/ipykernel_2068/1832093304.py:29: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_query, conn)
#     yearmonth   count
# 0     2008-07       9
# 1     2008-08    2806
# 2     2008-09    9643
# 3     2008-10    3544
# 4     2008-11    2857
# ..        ...     ...
# 172   2022-11  264690
# 173   2022-12  249281
# 174   2023-01  217014
# 175   2023-02  184360
# 176   2023-03   26716
#
# [177 rows x 2 columns]

# %% [markdown]
# ## Plotting
#
# Super! We have some results that we can use to interpret, let's plot them in order to make our findings more accessible to Yetunde at Stack Overflow.

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
ax = sns.barplot(x="yearmonth", y="count", hue="yearmonth", legend=False, data=df, palette="viridis")
plt.title("Number of Users per Year-Month")
plt.xlabel("Year-Month")
plt.ylabel("Count")
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for readability

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# You may have noticed how busy and inaccessible our `x-axis` has become with all those year-month dates. You may want to set custome x-ticks. You can do all manner of customisations, I simply chose to include the unique years in a list and gaps for the months - but that might not be the best way.

# %%
# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
ax = sns.barplot(x="yearmonth", y="count", data=df, palette="viridis", hue="yearmonth", legend=False)
plt.title("Number of Users per Year-Month")
plt.xlabel("Year-Month")
plt.ylabel("Count")
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for readability

# Create a list with the desired pattern
# Get unique years for dropdown options
unique_years = df['yearmonth'].str.split('-').str[0].unique()

year_month_pattern = []

for year in unique_years:
    year_month_pattern.append(year)
    year_month_pattern.extend([' '] * (df['yearmonth'].str.startswith(year).sum() - 1))

ax.set_xticklabels(year_month_pattern)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/60/1x07n04s69n5zj91gyj5fyrh0000gn/T/ipykernel_2068/3861281058.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(year_month_pattern)

# %% [markdown]
# ## Interactivity
#
# Let's make that chart a little more interactive. We can use Widgets to create a Year Selector, in order to look at how User Adoption changed throughout the years.
#
# We will need to add the `clear_output` function from the `IPython.display` library if we'd like the one chart to be updated.

# %%
from IPython.display import display, clear_output

def plot_interactive_chart(selected_year):
    filtered_df = df[df['yearmonth'].str.startswith(str(selected_year))]
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(x="yearmonth", y="count", data=filtered_df, palette="viridis", hue="yearmonth", legend=False)
    plt.title("Number of Users per Year-Month")
    plt.xlabel("Year-Month")
    plt.ylabel("Count")
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Get unique years for dropdown options
unique_years = df['yearmonth'].str.split('-').str[0].unique()

# Create a dropdown for year selection
year_dropdown = widgets.Dropdown(
    options=unique_years,
    description='Select Year:',
    disabled=False,
)

# Display Year Dropdown selector
display(year_dropdown)

# Define the function to update the plot based on the selected year
def update_plot(change):
    clear_output(wait=True)  # Clear the previous chart only
    display(year_dropdown)  # Redisplay the dropdown
    plot_interactive_chart(change.new)

# Connect the dropdown to the update function
year_dropdown.observe(update_plot, names='value')

# Display the dropdown and initial plot
plot_interactive_chart(unique_years[0])
# Out:
# Dropdown(description='Select Year:', index=1, options=('2008', '2009', '2010', '2011', '2012', '2013', '2014',…

# %%
# Display HEART metrics information
print('HEART Metrics for Stack Overflow:\n')
for metric, description in heart_metrics.items():
    print(f'{metric}: {description}')
# Out:
# HEART Metrics for Stack Overflow:
#
# Happiness: Measure of user satisfaction and happiness with the Questions & Answers product.
# Engagement: Measure of user interaction and activity on the platform.
# Adoption: Measure of user acquisition and growth of Stack Overflow user base.
# Retention: Measure of user retention and continued usage of the platform over time.
# Task Success: Measure of user ability to accomplish their goals and tasks effectively on Stack Overflow.

# %% [markdown]
# You can add more interactivity, even have some hover tooltip information with libraries like `plotly` - but for now that will suffice to make our results clear and accessible.

# %% [markdown]
# ## Launching with Voila
#
# All that's left is to launch with Voila. You should have installed `voila` with `pip` earlier on, but if you haven't you can do that now.
#
# You will want to run the notebook file with the command `voila`, then the filename. You can add the `--debug` flag in order to see debugging information in your terminal.
#
# The command should look something like this:

# %% [markdown]
# voila heart.ipynb --debug

# %% [markdown]
# ## Process Template
#
# Head over to the [Process Template found here](./process_template.md) to go through these steps with a checklist for each HEART metric, and good luck!
